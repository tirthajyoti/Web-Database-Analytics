# %% [markdown]
# # Notebook for crawling the UCI Machine Learning repository website + Convinient functions for downloading, summarizing or viewing information about various datasets

# %% [markdown]
# ### Impoer libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import requests
import os

# %% [markdown]
# ### Open the connection, read the HTML and parse it using BeautifulSoup library

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# Read the HTML from the URL and pass on to BeautifulSoup
url = 'https://archive.ics.uci.edu/ml/datasets.html?format=&task=&att=&area=&numAtt=&numIns=&type=&sort=nameUp&view=list'
print("Opening the file connection...")
uh= urllib.request.urlopen(url, context=ctx)
print("HTTP status",uh.getcode())
html =uh.read()
print(f"Reading done. Total {len(html)} characters read.")

# Soupify!
soup = BeautifulSoup(html, 'html5lib')
# Out:
# Opening the file connection...
# HTTP status 200
# Reading done. Total 114429 characters read.

# %% [markdown]
# ### Read all _p_-tag contents and extract dataset name, url, and description from them

# %%
lst=[]
for tag in soup.find_all('p'):
    lst.append(tag.contents)

i=0
description_dict={}
dataset_list=[]
for l in lst:
    if len(l)>2:
        if str(l[1]).find('datasets/')!=-1:
            string=str(l[1])
            s=re.search('">.*</a>',string)
            x,y=s.span()
            description_dict[string[x+2:y-4]]=(l[2])[2:]
            s=re.search("\".*\"",string)
            x,y=s.span()
            dataset_list.append(string[x+10:y-1])
            i+=1
print(f"{i} datasets read")
# Out:
# 425 datasets read

# %% [markdown]
# ### Function for scraping through individual dataset pages to extract the _Abstract_ and _dataurl_ (the page where actual data files reside)

# %%
def dataset_page_crawl(dataset):
    dataset_dict={}
    baseurl='https://archive.ics.uci.edu/ml/datasets/'
    url = baseurl+dataset
    dataset_dict['Dataset Page']=url
    #print("Opening the page:", url)
    try:
        uh= urllib.request.urlopen(url, context=ctx)
        html =uh.read().decode()
        soup=BeautifulSoup(html,'html5lib')
        #print(soup.text[:200])
        if soup.text.find("does not appear to exist")!=-1:
            print(f"{dataset} not found")
            return None
        else:
            dataurls = []
            for pclass in soup.find_all('p'):
                if (pclass.get_text().find('Abstract: '))!=-1:
                    dataset_dict['Abstract']=str(pclass.get_text())[len('Abstract: '):]
                    break # Breaking here is crucial. Otherwise the loop will progress through other p tags
                    # and put 'Not found' in the Abstract field
                else:
                    dataset_dict['Abstract']='Not found!'
            for link in soup.find_all('a'):
                if link.attrs['href'].find('machine-learning-databases')!=-1:
                    a=link.attrs['href']
                    a=a[2:]
                    dataurl="https://archive.ics.uci.edu/ml/"+a
                    dataurls.append(dataurl)
            
            # After finishing the for-loop with a-tags, the first dataurl is added to the dictionary 
            dataset_dict['dataurl']=dataurls[0]
            
        return dataset_dict
    except:
        print("Could not retrieve")
        return None

# %% [markdown]
# ### Crawl through all the dataset pages in the dataset list, store the abstract and dataset urls in a dictionary

# %%
i=0
baseurl='https://archive.ics.uci.edu/ml/datasets/'
dataset_dicts=[]
for dataset in dataset_list:
    a=dataset_page_crawl(dataset)
    if a!=None:
        dataset_dicts.append(a)
        i+=1
        print(f"Dataset {i} processed",end=', ')

print("\nTotal datasets analyzed: ",i)
# Out:
df_description=pd.DataFrame(data=list(description_dict.items()),columns=['Dataset','Abstract'])

# %% [markdown]
# #### Merge these two dataframes on the common _Abstract_ column

# %%
df_joined=df_description.merge(df_dataset,on='Abstract')
df_joined
# Out:
#                                                Dataset  \
# 0             3D Road Network (North Jutland, Denmark)
# 1                            AAAI 2013 Accepted Papers
# 2                            AAAI 2014 Accepted Papers
# 3                                              Abalone
# 4                      Abscisic Acid Signaling Network
# 5    Activities of Daily Living (ADLs) Recognition ...
# 6    Activity Recognition from Single Chest-Mounted...
# 7    Activity Recognition system based on Multisens...
# 8    Activity recognition with healthy older people...
# 9                                  Acute Inflammations
# 10                                               Adult
# 11                                         Air Quality
# 12                                         Air Quality
# 13                                  Airfoil Self-Noise
# 14                               Amazon Access Samples
# 15                         Amazon Commerce reviews set
# 16                         Amazon Commerce reviews set
# 17                                        Reuter_50_50
# 18                                        Reuter_50_50
# 19                                           Annealing
# 20                        Anonymous Microsoft Web Data
# 21                                Anuran Calls (MFCCs)
# 22                        Appliances energy prediction
# 23                        APS Failure at Scania Trucks
# 24                                              Arcene
# 25                                          Arrhythmia
# 26                               Artificial Characters
# 27                                Audiology (Original)
# 28                            Audiology (Standardized)
# 29                      Australian Sign Language signs
# ..                                                 ...
# 395                                   Urban Land Cover
# 396                                     URL Reputation
# 397                              US Census Data (1990)
# 398          User Identification From Walking Activity
# 399                            User Knowledge Modeling
# 400  USPTO Algorithm Challenge, run by NASA-Harvard...
# 401                                   Vertebral Column
# 402                     Vicon Physical Action Data Set
# 403            Volcanoes on Venus - JARtool experiment
# 404               Wall-Following Robot Navigation Data
# 405                              Water Treatment Plant
# 406            Waveform Database Generator (Version 1)
# 407            Waveform Database Generator (Version 1)
# 408            Waveform Database Generator (Version 2)
# 409            Waveform Database Generator (Version 2)
# 410  Wearable Computing: Classification of Body Pos...
# 411                                   Website Phishing
# 412  Weight Lifting Exercises monitored with Inerti...
# 413                                Wholesale customers
# 414                                            wiki4HE
# 415                                               Wilt
# 416                                               Wine
# 417                       Wireless Indoor Localization
# 418                                Yacht Hydrodynamics
# 419                                  YearPredictionMSD
# 420                                              Yeast
# 421                YouTube Comedy Slam Preference Data
# 422              YouTube Multiview Video Games Dataset
# 423                            YouTube Spam Collection
# 424                                                Zoo
#
#                                               Abstract  \
# 0    3D road network with highly accurate elevation...
# 1    This data set compromises the metadata for the...
# 2    This data set compromises the metadata for the...
# 3    Predict the age of abalone from physical measu...
# 4    The objective is to determine the set of boole...
# 5    This dataset comprises information regarding t...
# 6    The dataset collects data from a wearable acce...
# 7    This dataset contains temporal data from a Wir...
# 8    Sequential motion data from 14 healthy older p...
# 9    The data was created by a medical expert as a ...
# 10   Predict whether income exceeds $50K/yr based o...
# 11   Contains the responses of a gas multisensor de...
# 12   Contains the responses of a gas multisensor de...
# 13   NASA data set, obtained from a series of aerod...
# 14   Amazon's InfoSec is getting smarter about the ...
# 15   The dataset is used for authorship identificat...
# 16   The dataset is used for authorship identificat...
# 17   The dataset is used for authorship identificat...
# 18   The dataset is used for authorship identificat...
# 19                                Steel annealing data
# 20   Log of anonymous users of www.microsoft.com; p...
# 21   Acoustic features extracted from syllables of ...
# 22   Experimental data used to create regression mo...
# 23   The datasets' positive class consists of compo...
# 24   ARCENE's task is to distinguish cancer versus ...
# 25   Distinguish between the presence and absence o...
# 26   Dataset artificially generated by using first ...
# 27               Nominal audiology dataset from Baylor
# 28   Standardized version of the original audiology...
# 29   This data consists of sample of Auslan (Austra...
# ..                                                 ...
# 395  Classification of urban land cover using high ...
# 396  Anonymized 120-day subset of the ICML-09 URL d...
# 397  The USCensus1990raw data set contains a one pe...
# 398  The dataset collects data from an Android smar...
# 399  It is the real dataset about the students' kno...
# 400  Data used for USPTO Algorithm Competition. Con...
# 401  Data set containing values for six biomechanic...
# 402  The Physical Action Data Set includes 10 norma...
# 403  The JARtool project was a pioneering effort to...
# 404  The data were collected as the SCITOS G5 robot...
# 405               Multiple classes predict plant state
# 406                       CART book's waveform domains
# 407                       CART book's waveform domains
# 408                       CART book's waveform domains
# 409                       CART book's waveform domains
# 410  A dataset with 5 classes (sitting-down, standi...
# 411                                               \n\n
# 412  Six young health subjects were asked to perfor...
# 413  The data set refers to clients of a wholesale ...
# 414  Survey of faculty members from two Spanish uni...
# 415  High-resolution Remote Sensing data set (Quick...
# 416  Using chemical analysis determine the origin o...
# 417  Collected in indoor space by observing signal ...
# 418  Delft data set, used to predict the hydodynami...
# 419  Prediction of the release year of a song from ...
# 420  Predicting the Cellular Localization Sites of ...
# 421  This dataset provides user vote data on which ...
# 422  This dataset contains about 120k instances, ea...
# 423  It is a public set of comments collected for s...
# 424                   Artificial, 7 classes of animals
#
#                                           Dataset Page  \
# 0    https://archive.ics.uci.edu/ml/datasets/3D+Roa...
# 1    https://archive.ics.uci.edu/ml/datasets/AAAI+2...
# 2    https://archive.ics.uci.edu/ml/datasets/AAAI+2...
# 3      https://archive.ics.uci.edu/ml/datasets/Abalone
# 4    https://archive.ics.uci.edu/ml/datasets/Abscis...
# 5    https://archive.ics.uci.edu/ml/datasets/Activi...
# 6    https://archive.ics.uci.edu/ml/datasets/Activi...
# 7    https://archive.ics.uci.edu/ml/datasets/Activi...
# 8    https://archive.ics.uci.edu/ml/datasets/Activi...
# 9    https://archive.ics.uci.edu/ml/datasets/Acute+...
# 10       https://archive.ics.uci.edu/ml/datasets/Adult
# 11   https://archive.ics.uci.edu/ml/datasets/Air+Qu...
# 12   https://archive.ics.uci.edu/ml/datasets/Air+qu...
# 13   https://archive.ics.uci.edu/ml/datasets/Airfoi...
# 14   https://archive.ics.uci.edu/ml/datasets/Amazon...
# 15   https://archive.ics.uci.edu/ml/datasets/Amazon...
# 16   https://archive.ics.uci.edu/ml/datasets/Reuter...
# 17   https://archive.ics.uci.edu/ml/datasets/Amazon...
# 18   https://archive.ics.uci.edu/ml/datasets/Reuter...
# 19   https://archive.ics.uci.edu/ml/datasets/Annealing
# 20   https://archive.ics.uci.edu/ml/datasets/Anonym...
url = 'https://archive.ics.uci.edu/ml/datasets.html'
print("Opening the file connection...")
uh= urllib.request.urlopen(url, context=ctx)
print("HTTP status",uh.getcode())
html =uh.read()
print(f"Reading done. Total {len(html)} characters read.")

soup = BeautifulSoup(html, 'html5lib')
# Out:
# Opening the file connection...
# HTTP status 200
# Reading done. Total 364147 characters read.

# %%
lst=[]
for tag in soup.find_all('p'):
    lst.append(tag.contents)

# %%
lst_stats=[]
lst_dataset=[]
for l in lst:
    if str(l).find('datasets/')!=-1:
        
        string=str(l)
        s=re.search('">.*</a>',string)
        x,y=s.span()
        lst_dataset.append(string[x+2:y-4])
        
        lst_stats.append([x[0].replace(u'\xa0', u'') for x in lst[lst.index(l)+1:lst.index(l)+7]])

# %% [markdown]
# ### Create dataframes to store information about the datasets

# %% [markdown]
# #### Info dataframe

# %%
df_stats=pd.DataFrame(data=lst_stats,columns=['Data Type','Machine Learning Task',
                                              'Feature Type(s)','Number of samples','Number of features','Year'])

# %% [markdown]
# #### Names dataframe

# %%
df_names=pd.DataFrame(data=lst_dataset,columns=['Dataset'])

# %% [markdown]
# #### Merged dataframe

# %%
df_stats_joined=pd.concat([df_names,df_stats],axis=1)

# %% [markdown]
# ### Now, merge this name & info dataset with the previously created Abstract/dataurl dataframe. Perform an 'inner join' to match by _Abstract_ column

# %%
df_combined=df_joined.merge(df_stats_joined,on='Dataset')
df_combined
# Out:
#                                                Dataset  \
# 0             3D Road Network (North Jutland, Denmark)
# 1                            AAAI 2013 Accepted Papers
# 2                            AAAI 2014 Accepted Papers
# 3                                              Abalone
# 4                      Abscisic Acid Signaling Network
# 5    Activities of Daily Living (ADLs) Recognition ...
# 6    Activity Recognition from Single Chest-Mounted...
# 7    Activity Recognition system based on Multisens...
# 8    Activity recognition with healthy older people...
# 9                                  Acute Inflammations
# 10                                               Adult
# 11                                         Air Quality
# 12                                         Air Quality
# 13                                  Airfoil Self-Noise
# 14                               Amazon Access Samples
# 15                         Amazon Commerce reviews set
# 16                         Amazon Commerce reviews set
# 17                                        Reuter_50_50
# 18                                        Reuter_50_50
# 19                                           Annealing
# 20                        Anonymous Microsoft Web Data
# 21                                Anuran Calls (MFCCs)
# 22                        Appliances energy prediction
# 23                        APS Failure at Scania Trucks
# 24                                              Arcene
# 25                                          Arrhythmia
# 26                               Artificial Characters
# 27                                Audiology (Original)
# 28                            Audiology (Standardized)
# 29                      Australian Sign Language signs
# ..                                                 ...
# 395                                   Urban Land Cover
# 396                                     URL Reputation
# 397                              US Census Data (1990)
# 398          User Identification From Walking Activity
# 399                            User Knowledge Modeling
# 400  USPTO Algorithm Challenge, run by NASA-Harvard...
# 401                                   Vertebral Column
# 402                     Vicon Physical Action Data Set
# 403            Volcanoes on Venus - JARtool experiment
# 404               Wall-Following Robot Navigation Data
# 405                              Water Treatment Plant
# 406            Waveform Database Generator (Version 1)
# 407            Waveform Database Generator (Version 1)
# 408            Waveform Database Generator (Version 2)
# 409            Waveform Database Generator (Version 2)
# 410  Wearable Computing: Classification of Body Pos...
# 411                                   Website Phishing
# 412  Weight Lifting Exercises monitored with Inerti...
# 413                                Wholesale customers
# 414                                            wiki4HE
# 415                                               Wilt
# 416                                               Wine
# 417                       Wireless Indoor Localization
# 418                                Yacht Hydrodynamics
# 419                                  YearPredictionMSD
# 420                                              Yeast
# 421                YouTube Comedy Slam Preference Data
# 422              YouTube Multiview Video Games Dataset
# 423                            YouTube Spam Collection
# 424                                                Zoo
#
#                                               Abstract  \
# 0    3D road network with highly accurate elevation...
# 1    This data set compromises the metadata for the...
# 2    This data set compromises the metadata for the...
# 3    Predict the age of abalone from physical measu...
# 4    The objective is to determine the set of boole...
# 5    This dataset comprises information regarding t...
# 6    The dataset collects data from a wearable acce...
# 7    This dataset contains temporal data from a Wir...
# 8    Sequential motion data from 14 healthy older p...
# 9    The data was created by a medical expert as a ...
# 10   Predict whether income exceeds $50K/yr based o...
# 11   Contains the responses of a gas multisensor de...
# 12   Contains the responses of a gas multisensor de...
# 13   NASA data set, obtained from a series of aerod...
# 14   Amazon's InfoSec is getting smarter about the ...
# 15   The dataset is used for authorship identificat...
# 16   The dataset is used for authorship identificat...
# 17   The dataset is used for authorship identificat...
# 18   The dataset is used for authorship identificat...
# 19                                Steel annealing data
# 20   Log of anonymous users of www.microsoft.com; p...
# 21   Acoustic features extracted from syllables of ...
# 22   Experimental data used to create regression mo...
# 23   The datasets' positive class consists of compo...
# 24   ARCENE's task is to distinguish cancer versus ...
# 25   Distinguish between the presence and absence o...
# 26   Dataset artificially generated by using first ...
# 27               Nominal audiology dataset from Baylor
# 28   Standardized version of the original audiology...
# 29   This data consists of sample of Auslan (Austra...
# ..                                                 ...
# 395  Classification of urban land cover using high ...
# 396  Anonymized 120-day subset of the ICML-09 URL d...
# 397  The USCensus1990raw data set contains a one pe...
# 398  The dataset collects data from an Android smar...
# 399  It is the real dataset about the students' kno...
# 400  Data used for USPTO Algorithm Competition. Con...
# 401  Data set containing values for six biomechanic...
# 402  The Physical Action Data Set includes 10 norma...
# 403  The JARtool project was a pioneering effort to...
# 404  The data were collected as the SCITOS G5 robot...
# 405               Multiple classes predict plant state
# 406                       CART book's waveform domains
# 407                       CART book's waveform domains
# 408                       CART book's waveform domains
# 409                       CART book's waveform domains
# 410  A dataset with 5 classes (sitting-down, standi...
# 411                                               \n\n
# 412  Six young health subjects were asked to perfor...
# 413  The data set refers to clients of a wholesale ...
# 414  Survey of faculty members from two Spanish uni...
# 415  High-resolution Remote Sensing data set (Quick...
# 416  Using chemical analysis determine the origin o...
# 417  Collected in indoor space by observing signal ...
# 418  Delft data set, used to predict the hydodynami...
# 419  Prediction of the release year of a song from ...
# 420  Predicting the Cellular Localization Sites of ...
# 421  This dataset provides user vote data on which ...
# 422  This dataset contains about 120k instances, ea...
# 423  It is a public set of comments collected for s...
# 424                   Artificial, 7 classes of animals
#
#                                           Dataset Page  \
# 0    https://archive.ics.uci.edu/ml/datasets/3D+Roa...
# 407  https://archive.ics.uci.edu/ml//machine-learni...
# 408  https://archive.ics.uci.edu/ml//machine-learni...
# 409  https://archive.ics.uci.edu/ml//machine-learni...
# 410  https://archive.ics.uci.edu/ml//machine-learni...
# 411  https://archive.ics.uci.edu/ml//machine-learni...
# 412  https://archive.ics.uci.edu/ml//machine-learni...
# 413  https://archive.ics.uci.edu/ml//machine-learni...
# 414  https://archive.ics.uci.edu/ml//machine-learni...
# 415  https://archive.ics.uci.edu/ml//machine-learni...
# 416  https://archive.ics.uci.edu/ml//machine-learni...
# 417  https://archive.ics.uci.edu/ml//machine-learni...
# 418  https://archive.ics.uci.edu/ml//machine-learni...
# 419  https://archive.ics.uci.edu/ml//machine-learni...
# 420  https://archive.ics.uci.edu/ml//machine-learni...
# 421  https://archive.ics.uci.edu/ml//machine-learni...
# 422  https://archive.ics.uci.edu/ml//machine-learni...
# 423  https://archive.ics.uci.edu/ml//machine-learni...
# 424  https://archive.ics.uci.edu/ml//machine-learni...
#
#                                  Data Type  \
# 0                         Sequential, Text
# 1                             Multivariate
# 2                             Multivariate
# 3                             Multivariate
# 4                             Multivariate
# 5    Multivariate, Sequential, Time-Series
# 6      Univariate, Sequential, Time-Series
# 7    Multivariate, Sequential, Time-Series
# 8                               Sequential
# 9                             Multivariate
# 10                            Multivariate
# 11               Multivariate, Time-Series
# 12               Multivariate, Time-Series
# 13                            Multivariate
# 14              Time-Series, Domain-Theory
# 15       Multivariate, Text, Domain-Theory
# 16       Multivariate, Text, Domain-Theory
# 17       Multivariate, Text, Domain-Theory
# 18       Multivariate, Text, Domain-Theory
# 19                            Multivariate
# 20
# 21                            Multivariate
# 22               Multivariate, Time-Series
# 23                            Multivariate
# 24                            Multivariate
# 25                            Multivariate
# 26                            Multivariate
# 27                            Multivariate
# 28                            Multivariate
# 29               Multivariate, Time-Series
# ..                                     ...
# 395                           Multivariate
# 396              Multivariate, Time-Series
# 397                           Multivariate
# 398    Univariate, Sequential, Time-Series
# 399                           Multivariate
# 400                          Domain-Theory
# 401                           Multivariate
# 402                            Time-Series
# 403                                  Image
# 404               Multivariate, Sequential
# 405                           Multivariate
# 406           Multivariate, Data-Generator
# 407           Multivariate, Data-Generator
# 408           Multivariate, Data-Generator
# 409           Multivariate, Data-Generator
# 410                             Sequential
# 411                           Multivariate
# 412                           Multivariate
# 413                           Multivariate
# 414                           Multivariate
# 415                           Multivariate
# 416                           Multivariate
# 417                           Multivariate
# 418                           Multivariate
# 419                           Multivariate
# 420                           Multivariate
# 421                                   Text
# 422                     Multivariate, Text
# 423                                   Text
# 424                           Multivariate
#
#                         Machine Learning Task             Feature Type(s)  \
# 0                      Regression, Clustering                        Real
# 1                                  Clustering
# 2                                  Clustering
# 3                              Classification  Categorical, Integer, Real
# 4                            Causal-Discovery                     Integer
# 5                  Classification, Clustering
# 6                  Classification, Clustering                        Real
# 7                              Classification                        Real
# 8                              Classification                        Real
# 9                              Classification        Categorical, Integer
# 10                             Classification        Categorical, Integer
# 11                                 Regression                        Real
# 12                                 Regression                        Real
# 13                                 Regression                        Real
# 14   Regression, Clustering, Causal-Discovery
# 15                             Classification                        Real
# 16                             Classification                        Real
# 17                 Classification, Clustering                        Real
# 18                 Classification, Clustering                        Real
# 19                             Classification  Categorical, Integer, Real
# 20                        Recommender-Systems                 Categorical
# 21                 Classification, Clustering                        Real
# 22                                 Regression                        Real
# 23                             Classification               Integer, Real
# 24                             Classification                        Real
# 25                             Classification  Categorical, Integer, Real
# 26                             Classification  Categorical, Integer, Real
# 27                             Classification                 Categorical
# 28                             Classification                 Categorical
# 29                             Classification           Categorical, Real
# ..                                        ...                         ...
# 395                            Classification
# 396                            Classification               Integer, Real
# 397                                Clustering                 Categorical
# 398                Classification, Clustering                        Real
# 399                Classification, Clustering                     Integer
# 400                            Classification                     Integer
# 401                            Classification                        Real
# 402                            Classification                        Real
# 403                            Classification
# 404                            Classification                        Real
# 405                                Clustering               Integer, Real
# 406                            Classification                        Real
# 407                            Classification                        Real
# 408                            Classification                        Real
# 409                            Classification                        Real
# 410                            Classification               Integer, Real
# 411                            Classification                     Integer
# 412                            Classification                        Real
# 413                Classification, Clustering                     Integer
# 414  Regression, Clustering, Causal-Discovery
# 415                            Classification
# 416                            Classification               Integer, Real
# 417                            Classification                        Real
# 418                                Regression                        Real
# 419                                Regression                        Real
# 420                            Classification                        Real
# 421                            Classification
# 422                Classification, Clustering               Integer, Real
# 423                            Classification
# 424                            Classification        Categorical, Integer
#
#     Number of samples Number of features  Year
# 0              434874                  4  2013
# 1                 150                  5  2014
# 2                 399                  6  2014
# 3                4177                  8  1995
# 4                 300                 43  2008
# 5                2747                     2013
# 6                                         2014
# 7               42240                  6  2016
# 8               75128                  9  2016
# 9                 120                  6  2009
# 10              48842                 14  1996
# 11               9358                 15  2016
# 12               9358                 15  2016
# 13               1503                  6  2014
# 14              30000              20000  2011
# 15               1500              10000  2011
# 16               1500              10000  2011
# 17               2500              10000  2011
# 18               2500              10000  2011
# 19                798                 38
# 20              37711                294  1998
# 21               7195                 22  2017
# 22              19735                 29  2017
# 23              60000                171  2017
# 24                900              10000  2008
# 25                452                279  1998
# 26               6000                  7  1992
# 27                226                     1987
# 28                226                 69  1992
# 29               6650                 15  1999
# ..                ...                ...   ...
# 395               168                148  2014
# 396           2396130            3231961  2009
# 397           2458285                 68
# 398                                       2014
# 399               403                  5  2013
# 400               306                  5  2013
# 401               310                  6  2011
# 402              3000                 27  2011
# 403
# 404              5456                 24  2010
# 405               527                 38  1993
# 406              5000                 21  1988
# 407              5000                 21  1988
# 408              5000                 40  1988
# 409              5000                 40  1988
# 410            165632                 18  2013
# 411              1353                 10  2016
# 412             39242                152  2013
# 413               440                  8  2014
# 414               913                 53  2015
# 415              4889                  6  2014
# 416               178                 13  1991
# 417              2000                  7  2017
# 418               308                  7  2013
# 419            515345                 90  2011
# 420              1484                  8  1996
# 421           1138562                  3  2012
# 422            120000            1000000  2013
# 423              1956                  5  2017
# 424               101                 17  1990
#
# [425 rows x 10 columns]

# %% [markdown]
# ### Transform the type of _Number of samples_, _Number of features_, and _Year_ to integers for sorting and easy searching

# %%
df_combined['Year']=pd.to_numeric(df_combined['Year'],errors='coerce')
df_combined['Number of samples']=pd.to_numeric(df_combined['Number of samples'],errors='coerce')
df_combined['Number of features']=pd.to_numeric(df_combined['Number of features'],errors='coerce')

# %%
df_combined
# Out:
#                                                Dataset  \
# 0             3D Road Network (North Jutland, Denmark)
# 1                            AAAI 2013 Accepted Papers
# 2                            AAAI 2014 Accepted Papers
# 3                                              Abalone
# 4                      Abscisic Acid Signaling Network
# 5    Activities of Daily Living (ADLs) Recognition ...
# 6    Activity Recognition from Single Chest-Mounted...
# 7    Activity Recognition system based on Multisens...
# 8    Activity recognition with healthy older people...
# 9                                  Acute Inflammations
# 10                                               Adult
# 11                                         Air Quality
# 12                                         Air Quality
# 13                                  Airfoil Self-Noise
# 14                               Amazon Access Samples
# 15                         Amazon Commerce reviews set
# 16                         Amazon Commerce reviews set
# 17                                        Reuter_50_50
# 18                                        Reuter_50_50
# 19                                           Annealing
# 20                        Anonymous Microsoft Web Data
# 21                                Anuran Calls (MFCCs)
# 22                        Appliances energy prediction
# 23                        APS Failure at Scania Trucks
# 24                                              Arcene
# 25                                          Arrhythmia
# 26                               Artificial Characters
# 27                                Audiology (Original)
# 28                            Audiology (Standardized)
# 29                      Australian Sign Language signs
# ..                                                 ...
# 395                                   Urban Land Cover
# 396                                     URL Reputation
# 397                              US Census Data (1990)
# 398          User Identification From Walking Activity
# 399                            User Knowledge Modeling
# 400  USPTO Algorithm Challenge, run by NASA-Harvard...
# 401                                   Vertebral Column
# 402                     Vicon Physical Action Data Set
# 403            Volcanoes on Venus - JARtool experiment
# 404               Wall-Following Robot Navigation Data
# 405                              Water Treatment Plant
# 406            Waveform Database Generator (Version 1)
# 407            Waveform Database Generator (Version 1)
# 408            Waveform Database Generator (Version 2)
# 409            Waveform Database Generator (Version 2)
# 410  Wearable Computing: Classification of Body Pos...
# 411                                   Website Phishing
# 412  Weight Lifting Exercises monitored with Inerti...
# 413                                Wholesale customers
# 414                                            wiki4HE
# 415                                               Wilt
# 416                                               Wine
# 417                       Wireless Indoor Localization
# 418                                Yacht Hydrodynamics
# 419                                  YearPredictionMSD
# 420                                              Yeast
# 421                YouTube Comedy Slam Preference Data
# 422              YouTube Multiview Video Games Dataset
# 423                            YouTube Spam Collection
# 424                                                Zoo
#
#                                               Abstract  \
# 0    3D road network with highly accurate elevation...
# 1    This data set compromises the metadata for the...
# 2    This data set compromises the metadata for the...
# 3    Predict the age of abalone from physical measu...
# 4    The objective is to determine the set of boole...
# 5    This dataset comprises information regarding t...
# 6    The dataset collects data from a wearable acce...
# 7    This dataset contains temporal data from a Wir...
# 8    Sequential motion data from 14 healthy older p...
# 9    The data was created by a medical expert as a ...
# 10   Predict whether income exceeds $50K/yr based o...
# 11   Contains the responses of a gas multisensor de...
# 12   Contains the responses of a gas multisensor de...
# 13   NASA data set, obtained from a series of aerod...
# 14   Amazon's InfoSec is getting smarter about the ...
# 15   The dataset is used for authorship identificat...
# 16   The dataset is used for authorship identificat...
# 17   The dataset is used for authorship identificat...
# 18   The dataset is used for authorship identificat...
# 19                                Steel annealing data
# 20   Log of anonymous users of www.microsoft.com; p...
# 21   Acoustic features extracted from syllables of ...
# 22   Experimental data used to create regression mo...
# 23   The datasets' positive class consists of compo...
# 24   ARCENE's task is to distinguish cancer versus ...
# 25   Distinguish between the presence and absence o...
# 26   Dataset artificially generated by using first ...
# 27               Nominal audiology dataset from Baylor
# 28   Standardized version of the original audiology...
# 29   This data consists of sample of Auslan (Austra...
# ..                                                 ...
# 395  Classification of urban land cover using high ...
# 396  Anonymized 120-day subset of the ICML-09 URL d...
# 397  The USCensus1990raw data set contains a one pe...
# 398  The dataset collects data from an Android smar...
# 399  It is the real dataset about the students' kno...
# 400  Data used for USPTO Algorithm Competition. Con...
# 401  Data set containing values for six biomechanic...
# 402  The Physical Action Data Set includes 10 norma...
# 403  The JARtool project was a pioneering effort to...
# 404  The data were collected as the SCITOS G5 robot...
# 405               Multiple classes predict plant state
# 406                       CART book's waveform domains
# 407                       CART book's waveform domains
# 408                       CART book's waveform domains
# 409                       CART book's waveform domains
# 410  A dataset with 5 classes (sitting-down, standi...
# 411                                               \n\n
# 412  Six young health subjects were asked to perfor...
# 413  The data set refers to clients of a wholesale ...
# 414  Survey of faculty members from two Spanish uni...
# 415  High-resolution Remote Sensing data set (Quick...
# 416  Using chemical analysis determine the origin o...
# 417  Collected in indoor space by observing signal ...
# 418  Delft data set, used to predict the hydodynami...
# 419  Prediction of the release year of a song from ...
# 420  Predicting the Cellular Localization Sites of ...
# 421  This dataset provides user vote data on which ...
# 422  This dataset contains about 120k instances, ea...
# 423  It is a public set of comments collected for s...
# 424                   Artificial, 7 classes of animals
#
#                                           Dataset Page  \
# 0    https://archive.ics.uci.edu/ml/datasets/3D+Roa...
# 1    https://archive.ics.uci.edu/ml/datasets/AAAI+2...
# 2    https://archive.ics.uci.edu/ml/datasets/AAAI+2...
# 3      https://archive.ics.uci.edu/ml/datasets/Abalone
# 4    https://archive.ics.uci.edu/ml/datasets/Abscis...
# 5    https://archive.ics.uci.edu/ml/datasets/Activi...
# 6    https://archive.ics.uci.edu/ml/datasets/Activi...
# 7    https://archive.ics.uci.edu/ml/datasets/Activi...
# 8    https://archive.ics.uci.edu/ml/datasets/Activi...
# 9    https://archive.ics.uci.edu/ml/datasets/Acute+...
# 10       https://archive.ics.uci.edu/ml/datasets/Adult
# 11   https://archive.ics.uci.edu/ml/datasets/Air+Qu...
# 12   https://archive.ics.uci.edu/ml/datasets/Air+qu...
# 13   https://archive.ics.uci.edu/ml/datasets/Airfoi...
# 14   https://archive.ics.uci.edu/ml/datasets/Amazon...
# 15   https://archive.ics.uci.edu/ml/datasets/Amazon...
# 16   https://archive.ics.uci.edu/ml/datasets/Reuter...
# 424  https://archive.ics.uci.edu/ml//machine-learni...
#
#                                  Data Type  \
# 0                         Sequential, Text
# 1                             Multivariate
# 2                             Multivariate
# 3                             Multivariate
# 4                             Multivariate
# 5    Multivariate, Sequential, Time-Series
# 6      Univariate, Sequential, Time-Series
# 7    Multivariate, Sequential, Time-Series
# 8                               Sequential
# 9                             Multivariate
# 10                            Multivariate
# 11               Multivariate, Time-Series
# 12               Multivariate, Time-Series
# 13                            Multivariate
# 14              Time-Series, Domain-Theory
# 15       Multivariate, Text, Domain-Theory
# 16       Multivariate, Text, Domain-Theory
# 17       Multivariate, Text, Domain-Theory
# 18       Multivariate, Text, Domain-Theory
# 19                            Multivariate
# 20
# 21                            Multivariate
# 22               Multivariate, Time-Series
# 23                            Multivariate
# 24                            Multivariate
# 25                            Multivariate
# 26                            Multivariate
# 27                            Multivariate
# 28                            Multivariate
# 29               Multivariate, Time-Series
# ..                                     ...
# 395                           Multivariate
# 396              Multivariate, Time-Series
# 397                           Multivariate
# 398    Univariate, Sequential, Time-Series
# 399                           Multivariate
# 400                          Domain-Theory
# 401                           Multivariate
# 402                            Time-Series
# 403                                  Image
# 404               Multivariate, Sequential
# 405                           Multivariate
# 406           Multivariate, Data-Generator
# 407           Multivariate, Data-Generator
# 408           Multivariate, Data-Generator
# 409           Multivariate, Data-Generator
# 410                             Sequential
# 411                           Multivariate
# 412                           Multivariate
# 413                           Multivariate
# 414                           Multivariate
# 415                           Multivariate
# 416                           Multivariate
# 417                           Multivariate
# 418                           Multivariate
# 419                           Multivariate
# 420                           Multivariate
# 421                                   Text
# 422                     Multivariate, Text
# 423                                   Text
# 424                           Multivariate
#
#                         Machine Learning Task             Feature Type(s)  \
# 0                      Regression, Clustering                        Real
# 1                                  Clustering
# 2                                  Clustering
# 3                              Classification  Categorical, Integer, Real
# 4                            Causal-Discovery                     Integer
# 5                  Classification, Clustering
# 6                  Classification, Clustering                        Real
# 7                              Classification                        Real
# 8                              Classification                        Real
# 9                              Classification        Categorical, Integer
# 10                             Classification        Categorical, Integer
# 11                                 Regression                        Real
# 12                                 Regression                        Real
# 13                                 Regression                        Real
# 14   Regression, Clustering, Causal-Discovery
# 15                             Classification                        Real
# 16                             Classification                        Real
# 17                 Classification, Clustering                        Real
# 18                 Classification, Clustering                        Real
# 19                             Classification  Categorical, Integer, Real
# 20                        Recommender-Systems                 Categorical
# 21                 Classification, Clustering                        Real
# 22                                 Regression                        Real
# 23                             Classification               Integer, Real
# 24                             Classification                        Real
# 25                             Classification  Categorical, Integer, Real
# 26                             Classification  Categorical, Integer, Real
# 27                             Classification                 Categorical
# 28                             Classification                 Categorical
# 29                             Classification           Categorical, Real
# ..                                        ...                         ...
# 395                            Classification
# 396                            Classification               Integer, Real
# 397                                Clustering                 Categorical
# 398                Classification, Clustering                        Real
# 399                Classification, Clustering                     Integer
# 400                            Classification                     Integer
# 401                            Classification                        Real
# 402                            Classification                        Real
# 403                            Classification
# 404                            Classification                        Real
# 405                                Clustering               Integer, Real
# 406                            Classification                        Real
# 407                            Classification                        Real
# 408                            Classification                        Real
# 409                            Classification                        Real
# 410                            Classification               Integer, Real
# 411                            Classification                     Integer
# 412                            Classification                        Real
# 413                Classification, Clustering                     Integer
# 414  Regression, Clustering, Causal-Discovery
# 415                            Classification
# 416                            Classification               Integer, Real
# 417                            Classification                        Real
# 418                                Regression                        Real
# 419                                Regression                        Real
# 420                            Classification                        Real
# 421                            Classification
# 422                Classification, Clustering               Integer, Real
# 423                            Classification
# 424                            Classification        Categorical, Integer
#
#      Number of samples  Number of features    Year
# 0             434874.0                 4.0  2013.0
# 1                150.0                 5.0  2014.0
# 2                399.0                 6.0  2014.0
# 3               4177.0                 8.0  1995.0
# 4                300.0                43.0  2008.0
# 5               2747.0                 NaN  2013.0
# 6                  NaN                 NaN  2014.0
# 7              42240.0                 6.0  2016.0
# 8              75128.0                 9.0  2016.0
# 9                120.0                 6.0  2009.0
# 10             48842.0                14.0  1996.0
# 11              9358.0                15.0  2016.0
# 12              9358.0                15.0  2016.0
# 13              1503.0                 6.0  2014.0
# 14             30000.0             20000.0  2011.0
# 15              1500.0             10000.0  2011.0
# 16              1500.0             10000.0  2011.0
# 17              2500.0             10000.0  2011.0
# 18              2500.0             10000.0  2011.0
# 19               798.0                38.0     NaN
# 20             37711.0               294.0  1998.0
# 21              7195.0                22.0  2017.0
# 22             19735.0                29.0  2017.0
# 23             60000.0               171.0  2017.0
# 24               900.0             10000.0  2008.0
# 25               452.0               279.0  1998.0
# 26              6000.0                 7.0  1992.0
# 27               226.0                 NaN  1987.0
# 28               226.0                69.0  1992.0
# 29              6650.0                15.0  1999.0
# ..                 ...                 ...     ...
# 395              168.0               148.0  2014.0
# 396          2396130.0           3231961.0  2009.0
# 397          2458285.0                68.0     NaN
# 398                NaN                 NaN  2014.0
# 399              403.0                 5.0  2013.0
# 400              306.0                 5.0  2013.0
# 401              310.0                 6.0  2011.0
# 402             3000.0                27.0  2011.0
# 403                NaN                 NaN     NaN
# 404             5456.0                24.0  2010.0
# 405              527.0                38.0  1993.0
# 406             5000.0                21.0  1988.0
# 407             5000.0                21.0  1988.0
# 408             5000.0                40.0  1988.0
# 409             5000.0                40.0  1988.0
# 410           165632.0                18.0  2013.0
# 411             1353.0                10.0  2016.0
# 412            39242.0               152.0  2013.0
# 413              440.0                 8.0  2014.0
# 414              913.0                53.0  2015.0
# 415             4889.0                 6.0  2014.0
# 416              178.0                13.0  1991.0
# 417             2000.0                 7.0  2017.0
# 418              308.0                 7.0  2013.0
# 419           515345.0                90.0  2011.0
# 420             1484.0                 8.0  1996.0
# 421          1138562.0                 3.0  2012.0
# 422           120000.0           1000000.0  2013.0
# 423             1956.0                 5.0  2017.0
# 424              101.0                17.0  1990.0
#
# [425 rows x 10 columns]

# %% [markdown]
# ### File download helper function

# %%
def download_file(url,directory):
    local_filename = directory+'/'+url.split('/')[-1]
    # NOTE the stream=True parameter
    r = requests.get(url, stream=True)
    with open(local_filename, 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024): 
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                #f.flush()
    #return local_filename

# %% [markdown]
# ### Function for downloading the data set from a page

# %%
def download_from_url(url,dataset):    
    
    cwd = os.getcwd()
    local_directory = cwd+'\\'+dataset
    if not os.path.exists(local_directory):
        os.makedirs(local_directory)

    uh= urllib.request.urlopen(url, context=ctx)
    html =uh.read().decode()
    soup=BeautifulSoup(html,'html5lib')

    links=[]
    for link in soup.find_all('a'):
        links.append(link.attrs['href'])
    
    links_to_download=[]

    if 'Index' in links:
        idx=links.index('Index')
    else:
        idx=len(links)-2
    for i in range(idx+1,len(links)):
        links_to_download.append(url+str(links[i]))

    for file_url in links_to_download:
        download_file(file_url,local_directory)
    
    print (f"Downloaded dataset from {url}")

# %% [markdown]
# ### Function to download data by dataset name

# %%
def download_dataset(dataset):
    
    try:
        url=df_combined[df_combined['Dataset']==dataset]['Dataset Page'].values[0]
    except:
        print("Something wrong in the dataset name!")
        return None
    
    print(f"Downloading the dataset: {dataset}")
    download_from_url(url, dataset)

# %% [markdown]
# ### Testing the download function

# %%
download_dataset('Wireless Indoor Localization')
# Out:
# Downloading the dataset: Wireless Indoor Localization
# Downloaded dataset from https://archive.ics.uci.edu/ml/datasets/Wireless+Indoor+Localization

# %% [markdown]
# ### Function for finding more information for any dataset

# %%
def dataset_information(dataset):
    
    try:
        url=df_combined[df_combined['Dataset']==dataset]['Dataset Page'].values[0]
    except:
        print("Something wrong in the dataset name!")
        return None
    
    try:
        dataset_info={}
        uh= urllib.request.urlopen(url, context=ctx)
        html =uh.read()
        soup = BeautifulSoup(html, 'html5lib')
        
        tag=soup.find('p',text='Data Set Information:')
        if tag!=None:
            text=tag.find_next('p').get_text()
            print("DATASET INFORMATION")
            print("="*50)
            print(text)
            print("="*50)
            print("\n")
            dataset_info['Dataset info']=text
        else:
            print("No information about the dataset could be found on its page!")
        
        tag=soup.find('p',text='Source:')
        if tag!=None:
            text=tag.find_next('p').get_text()
            print("SOURCE")
            print("="*50)
            print(text)
            print("="*50)
            print("\n")
            dataset_info['Dataset Source']=text
        else:
            print("No information about the source of dataset could be found on its page!")
        
        return dataset_info
    except:
        print("Could not connect")

# %%
d=dataset_information('Iris')
# Out:
# DATASET INFORMATION
# ==================================================
# This is perhaps the best known database to be found in the pattern recognition literature.  Fisher's paper is a classic in the field and is referenced frequently to this day.  (See Duda & Hart, for example.)  The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Predicted attribute: class of iris plant.
#
# This is an exceedingly simple domain.
#
# This data differs from the data presented in Fishers article (identified by Steve Chadwick,  spchadwick '@' espeedaz.net ).  The 35th sample should be: 4.9,3.1,1.5,0.2,"Iris-setosa" where the error is in the fourth feature. The 38th sample: 4.9,3.6,1.4,0.1,"Iris-setosa" where the errors are in the second and third features.
# ==================================================
#
#
# SOURCE
# ==================================================
# Creator:
#
# R.A. Fisher
#
# Donor:
#
# Michael Marshall (MARSHALL%PLU '@' io.arc.nasa.gov)
# ==================================================
